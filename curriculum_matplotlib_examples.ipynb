# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = list(range(150))
plt.plot(x)

# %%
x = list(range(150))
plt.xlim(-20, 200)
plt.ylim(-5, 160)
plt.plot(x, c='red')

# %%
from random import randint

# Some random data
x1 = [randint(-5, 45) + n for n in range(150)]
x2 = [x + randint(-5, 23) for x in x1]

# we can use the alpha kwarg to define how transparent the color is
plt.plot(x1, c='blue', alpha=0.6)
plt.plot(x2, c='red', alpha=0.9)
plt.plot(x, c='green')
